# %%
# Run GPU diagnostics
import sys
from pathlib import Path

# Add pytutorials the path (one level up from notebooks/) to sys.path
sys.path.append(str(Path.cwd().parent))

from pytutorials.utils.diagnostics import test_cuda_tensor_ops

# %%
results = test_cuda_tensor_ops(verbose=True)
print(results)
